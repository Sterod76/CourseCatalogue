# %% [markdown]
# # Reversign delle API di Course Catalogue?
#
# Sembra un poco surreale ma pare che Course Catalogue esponga vari endpoint per accedere ai dati... ossia ci sono già varie API pubbliche (che i sistemisti non conoscono?).
#
# ## 1. Accesso parametrico agli insegnamenti in Catalogo
#
# Partendo da quanto indicato in GDA è emerso che è possibile accedere agli insegnamenti con degli indirizzi parametrici di cui sono forniti alcuni esempi a seguire.
#
# Per l'insegnamento magistrale **217BB "Accelerator Physics"** abbiamo (parametri separati artificialmente... va concatenato tutto nell'URL)
#
# `https://unipi.coursecatalogue.cineca.it/af/2024?`
# * `corso=WFI-LM&`
# * `annoOrdinamento=2023&`
# * `ad=217BB`
#
# Per l'insegnamento **288BB "Astrofisica Generale"** abbiamo invece
#
# `https://unipi.coursecatalogue.cineca.it/af/2024?`
# * `corso=FIS-L&`
# * `annoOrdinamento=2017&`
# * `ad=288BB`
#
# Ed esiste anche un modo per accedere alle diverse varianti di un insegnamento, come nel caso di **632AA "Analisi Matematica"**
#
# `https://unipi.coursecatalogue.cineca.it/af/2024?`
# * `corso=FIS-L&`
# * `annoOrdinamento=2017&`
# * `ad=632AA&`
# * `domPart=A`
#
# In conclusione c'è una sintassi precisa e bisogna conoscere semplicemente la giusta combinazione di codice dell'insegnamento e dell'anno dell'Ordinamento. I codici recuperati su GDA permettono di specificare degli ulteriori parametri (di fatto, guardando come risponde il sistema, opzionali) fra cui
#
# * `pds` per indicare il piano di studio... qui vanno conosciuti i codici, che sono gli stessi che compaiono in GDA. Non sembra particolarmente utile ma cambia la modalità di visualizzazione dell'insegnamento sulla pagina web.
# * `coorte` anno della coorte, questo potrebbe essere interessante... in assenza del parametro non mi è chiaro cosa sceglie il sistema
# * `sede` tipicamente uguale a 1059 che credo significhi Università di Pisa
# * `lingua` ... non chiaro perché indicarlo dato che è una proprietà dell'insegnamento
# * `modDid` significato non chiaro e tipicamente di valore C... che mi pare di capire stia per "Convenzionale".
#
# ## 2. Digging deeper
#
# Guardando il codice HTML a questi indirizzi non si capisce nulla, e il contenuto vero richiede Javascript per essere caricato. Secondo GPT questo avviene tramite la app Angular. Non è chiaro se sia vero ma usando tasto destro inspect e DevTools su Chrome e andando sul tab Network è possibile rintracciare la chiamate che permettono di popolare le pagine dei corsi... ossia - *surprise-surprise* - il sito di Course Catalogue ha già una inferfaccia API ed espone già un tot di endpoint.
#
# Per esempio, è possibile ottenere un `JSON` con tutte le info dell'insegnamento con
#
# `https://unipi.coursecatalogue.cineca.it/api/v1/attivitaFormativa?`
# * `aaOfferta=2024&`
# * `corso=WFI-LM&`
# * `annoOrdinamento=2023&`
# * `ad=217BB`
#
# Diversamente dal caso precedente, qui il catalogo fornisce **DIRETTAMENTE** i dati JSON dell'insegnamento, senza passare da Javascript e quindi con una richiesta web standard.
#
# ## 3. Il mistero dei codici interni Cineca
#
# I link del Catalogo hanno tipicamente dei codici complessi la cui origine non è chiara. Per esempio i link web parametrici di cui sopra vengono reindirizzati su questi codici di orgine ignota. Anche questi tuttavia derivano da una interrogazione, evidentemente, e qui è stata rintracciata. D'altra parte se esiste un redirect, è possibile "chiedere" al catalogo quali siano questi codici.
#
# Quando viene caricato l'URL..
#
# `https://unipi.coursecatalogue.cineca.it/af/2024?corso=WFI-LM&annoOrdinamento=2023&ad=217BB`
#
# questo viene reindirizzato a
#
# `https://unipi.coursecatalogue.cineca.it/insegnamenti/2024/52567_697863_71649/2023/52567/10452?annoOrdinamento=2023`
#
# dove `52567_697863_71649` è un esempio del codice misterioso dell'insegnamento citato sopra, che non è chiaro come riagganciare al codice GDA `217BB`. Questo è evidentemente un codice interno al database Cineca. Ebbene... nel JSON di cui sopra il codice compare come valore della chiava `cod`.

# %%
# Esempio: come interrogare Course Catalogue per avere il codice interno di 217BB

import requests
import yaml

targetFile = "infoAF2.yaml"
url = "https://unipi.coursecatalogue.cineca.it/api/v1/attivitaFormativa"
params = {
    "aaOfferta": 2024,
    "corso": "WFI-LM",
    "annoOrdinamento": 2023,
    "ad": "323BB"
}
response = requests.get(url, params=params)

if response.status_code == 200:

    data = response.json()
    print(f"Titolo: {data['des_it']}")
    print(f"SSD:    {data['ssd']}")
    print(f"CFU:    {data['crediti']} CFU")
    docenti = ['     -> '+xx['des'] for xx in data['docenti']]
    print(f"Docenti:")
    print("\n".join(docenti))
    print(f"Codice interno: {data['cod']}")
    with open(targetFile, "w", encoding="utf-8") as file_yaml:
        yaml.dump(data, file_yaml, allow_unicode=True, sort_keys=False)
    
else:
    print(f"Errore nella richiesta: {response.status_code}")
# Out:
# Errore nella richiesta: 404

# %% [markdown]
# ## 4. Altri endpoint esposti da Course Catalogue
#
# A questo punto, ho esplorato con DevTools varie altre pagine... fra cui quella di ricerca degli insegnamenti. Ricerca fruttuosa perché sembra possibile fare una richiesta di tipo POST (con dei dati inviati al server) al seguente e nuovo endpoint
#
# `https://unipi.coursecatalogue.cineca.it/api/v1/ricercaInsegnamenti`
#
# Nel *payload* vanno indicati i parametri di ricerca nel formato di un dizionario JSON. Sotto un esempio di utilizzo. Si noti:
#
# * diversamente dal form di ricerca web, qui è possibile specificare anche `None` nel parametro di anno di offerta `anno_off`, e ottenerne così una lista di TUTTE le risposte possibili di tutti gli anni.
# * nel campo `insegnamento` si può inserire sia il codice che parti del titolo
# * `anno_imm` volendo seleziona la coorte
# * `corsiSearchString` non è chiaro che significhi, non è esposto sul form di ricerca.
# * La richiesta diretta all'API aggira alcuni dei limiti dei form online, per esempio è possibile richiedere TUTTI gli insegnamenti erogati presso il Dipartimento di Fisica nel 2024. Per indicare il dipartimento va usato il codice del dipartimento, che per fisica è 10184.

# %%
# Interrogazione dell'API per ottenere informazioni sugli insegnamenti

import requests
import yaml

targetFile = "searchInsegnamenti.yaml"
url = "https://unipi.coursecatalogue.cineca.it/api/v1/ricercaInsegnamenti"
payload = {
    "insegnamento": "",
    "docente": None,
    "anno_imm": None,
    "anno_off": "2024",   
    "dipartimento": 10184,
    "ssdSearchString": None,
    "tipoCorso": None,
    "lingua": None,
    "corsiSearchString": None,
}
headers = {"Content-Type": "application/json"}
response = requests.post(url, json=payload, headers=headers)

if response.status_code == 200:
    risultati = response.json()
    for tmp in risultati:
        print(f"[{tmp['adCod']}] {tmp['des_it']}")
        print(f"    Percorso:     {tmp['corso_percorso_des_it']}")
        print(f"    Codice:       {tmp['cod']}")
        print(f"    Coorte:       {tmp['corso_aa']}") 
        print(f"    Dipartimento: {tmp['dip_des_it']}")       
        print()
    with open(targetFile, "w", encoding="utf-8") as f:
        yaml.dump(risultati, f, allow_unicode=True, sort_keys=False)
else:
    print(f"Errore nella richiesta: {response.status_code}")
    print(response.text)
# Out:
# [033BB] LABORATORIO 2 a
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [367BB] ELEMENTI DI COMPUTAZIONE
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] PROVA FINALE
#     Percorso:     FISICA TEORICA
#     Codice:       1
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] PROVA FINALE
#     Percorso:     INTERAZIONI FONDAMENTALI
#     Codice:       1
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] PROVA FINALE
#     Percorso:     FISICA DELLA MATERIA
#     Codice:       1
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] PROVA FINALE
#     Percorso:     FISICA MEDICA
#     Codice:       1
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] PROVA FINALE
#     Percorso:     ASTRONOMIA E ASTROFISICA
#     Codice:       1
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] PROVA FINALE
#     Percorso:     GENERALE
#     Codice:       1
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [413BB] MODULO A
#     Percorso:     INTERAZIONI FONDAMENTALI
#     Codice:       1
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [104BB] MEDICAL PHYSICS LABORATORY A / LABORATORIO DI FISICA MEDICA
#     Percorso:     FISICA MEDICA
#     Codice:       1
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [403BB] BIO-SYSTEMS LAB - I MODULO
#     Percorso:     GENERALE
#     Codice:       1
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [258BB] MECCANICA QUANTISTICA (CORSO A)
#     Percorso:     FIS2017
#     Codice:       1-A
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [029BB] FISICA 2 (CORSO A)
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1-A
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [632AA] ANALISI MATEMATICA (CORSO A)
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1-A
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [028BB] FISICA 1 (CORSO A)
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1-A
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [718AA] GEOMETRIA (CORSO A)
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1-A
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [258BB] MECCANICA QUANTISTICA (CORSO B)
#     Percorso:     FIS2017
#     Codice:       1-B
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [029BB] FISICA 2 (CORSO B)
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1-B
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [632AA] ANALISI MATEMATICA (CORSO B)
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1-B
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [028BB] FISICA 1 (CORSO B)
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1-B
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [718AA] GEOMETRIA (CORSO B)
#     Percorso:     CURRICULUM COMUNE
#     Codice:       1-B
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [033BB] LABORATORIO 2 b
#     Percorso:     CURRICULUM COMUNE
#     Codice:       2
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [367BB] LABORATORIO DI FISICA
#     Percorso:     CURRICULUM COMUNE
#     Codice:       2
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] ALTRE CONOSCENZE UTILI PER L'INSERIMENTO NEL MONDO DEL LAVORO
#     Percorso:     FISICA TEORICA
#     Codice:       2
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] ALTRE CONOSCENZE UTILI PER L'INSERIMENTO NEL MONDO DEL LAVORO
#     Percorso:     INTERAZIONI FONDAMENTALI
#     Codice:       2
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] ALTRE CONOSCENZE UTILI PER L'INSERIMENTO NEL MONDO DEL LAVORO
#     Percorso:     FISICA DELLA MATERIA
#     Codice:       2
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] ALTRE CONOSCENZE UTILI PER L'INSERIMENTO NEL MONDO DEL LAVORO
#     Percorso:     FISICA MEDICA
#     Codice:       2
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] ALTRE CONOSCENZE UTILI PER L'INSERIMENTO NEL MONDO DEL LAVORO
#     Percorso:     ASTRONOMIA E ASTROFISICA
#     Codice:       2
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [125ZW] ALTRE CONOSCENZE UTILI PER L'INSERIMENTO NEL MONDO DEL LAVORO
#     Percorso:     GENERALE
#     Codice:       2
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [413BB] MODULO B
#     Percorso:     INTERAZIONI FONDAMENTALI
#     Codice:       2
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [104BB] MEDICAL PHYSICS LABORATORY B / LABORATORIO DI FISICA MEDICA
#     Percorso:     FISICA MEDICA
#     Codice:       2
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [403BB] BIO-SYSTEMS LAB- II MODULO
#     Percorso:     GENERALE
#     Codice:       2
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [026BB] FISICA DEI MATERIALI PER LA FOTONICA
#     Percorso:     FIS2017
#     Codice:       49754_686546_66692
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [034BB] LABORATORIO 3
#     Percorso:     FIS2017
#     Codice:       49754_686549_66706
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [118ZW] PROVA FINALE
#     Percorso:     FIS2017
#     Codice:       49754_686551_66713
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [041BB] STRUTTURA DELLA MATERIA
#     Percorso:     FIS2017
#     Codice:       49754_686554_66716
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [042BB] TECNOLOGIE DIGITALI
#     Percorso:     FIS2017
#     Codice:       49754_686555_66717
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [175BB] METODI MATEMATICI 2
#     Percorso:     FIS2017
#     Codice:       49754_686557_70219
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [175BB] METODI MATEMATICI 2
#     Percorso:     FIS2017
#     Codice:       49754_686557_70219
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [224CC] CHIMICA FISICA E LABORATORIO
#     Percorso:     FIS2017
#     Codice:       49754_686558_70530
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [180BB] ELEMENTI DI STORIA DELLA FISICA
#     Percorso:     FIS2017
#     Codice:       49754_686559_70532
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [181BB] FISICA DELL'ATMOSFERA
#     Percorso:     FIS2017
#     Codice:       49754_686560_70533
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [181BB] FISICA DELL'ATMOSFERA
#     Percorso:     CURRICULUM COMUNE
#     Codice:       49754_686560_70533
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [250BB] INTRODUZIONE ALLA FISICA SUBNUCLEARE
#     Percorso:     FIS2017
#     Codice:       49754_686561_73450
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [285BB] TECNOLOGIE DIGITALI S
#     Percorso:     FIS2017
#     Codice:       49754_686562_74422
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [286BB] TEORIA DEI GRUPPI
#     Percorso:     FIS2017
#     Codice:       49754_686563_74423
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [288BB] ASTROFISICA GENERALE
#     Percorso:     FIS2017
#     Codice:       49754_686565_74737
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [289BB] FLUIDODINAMICA
#     Percorso:     FIS2017
#     Codice:       49754_686566_74739
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [672AA] EQUAZIONI ALLE DERIVATE PARZIALI
#     Percorso:     FIS2017
#     Codice:       49754_686567_74870
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [187DD] ELEMENTI DI GEOFISICA
#     Percorso:     FIS2017
#     Codice:       49754_686568_75606
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [814II] PRINCIPI MECCANICI PER L'INGEGNERIA NUCLEARE
#     Percorso:     FIS2017
#     Codice:       49754_686569_75608
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [815II] PRINCIPI TERMICI I PER L'INGEGNERIA NUCLEARE
#     Percorso:     FIS2017
#     Codice:       49754_686570_75609
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [347BB] LABORATORIO 3 AVANZATO
#     Percorso:     FIS2017
#     Codice:       49754_686571_76168
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [349BB] MECCANICA QUANTISTICA AVANZATA
#     Percorso:     FIS2017
#     Codice:       49754_686572_76231
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [366BB] INFORMATICA CON LABORATORIO
#     Percorso:     FIS2017
#     Codice:       49754_686574_76789
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [366BB] INFORMATICA CON LABORATORIO
#     Percorso:     FIS2017
#     Codice:       49754_686574_76789
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [415BB] PHYSICS OF SOUND
#     Percorso:     FIS2017
#     Codice:       49754_686575_77810
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [258BB] MECCANICA QUANTISTICA
#     Percorso:     FIS2017
#     Codice:       49754_695820_73461
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [248BB] FISICA 3
#     Percorso:     FIS2017
#     Codice:       49754_695821_73448
#     Coorte:       2022
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [056CC] CHIMICA GENERALE
#     Percorso:     CURRICULUM COMUNE
#     Codice:       49755_686619_66687
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [029BB] FISICA 2
#     Percorso:     CURRICULUM COMUNE
#     Codice:       49755_686620_66695
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [033BB] LABORATORIO 2
#     Percorso:     CURRICULUM COMUNE
#     Codice:       49755_686621_66705
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [035BB] MECCANICA CLASSICA
#     Percorso:     CURRICULUM COMUNE
#     Codice:       49755_686622_66708
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [037BB] METODI MATEMATICI 1
#     Percorso:     CURRICULUM COMUNE
#     Codice:       49755_686623_66711
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [637AA] COMPLEMENTI DI ANALISI MATEMATICA
#     Percorso:     CURRICULUM COMUNE
#     Codice:       49755_686624_74738
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [080BB] ELETTRONICA E SENSORI
#     Percorso:     GENERALE
#     Codice:       51376_686668_66814
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [091BB] COMPACT STAR PHYSICS S / FISICA DELLE STELLE COMPATTE S
#     Percorso:     GENERALE
#     Codice:       51376_686671_66831
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [092BB] FISICA DELLE SUPERFICI E INTERFACCE
#     Percorso:     GENERALE
#     Codice:       51376_686672_66833
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [107BB] ACCELERATOR PHYSICS S / MACCHINE ACCELERATRICI S
#     Percorso:     GENERALE
#     Codice:       51376_686673_66880
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [124BB] NUCLEAR MAGNETIC RESONANCE / RISONANZA MAGNETICA NUCLEARE
#     Percorso:     GENERALE
#     Codice:       51376_686677_66913
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [140BB] GRAVITATION THEORY S / TEORIE DELLA GRAVITAZIONE S
#     Percorso:     GENERALE
#     Codice:       51376_686678_66941
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [170BB] EXOPLANETARY SYSTEMS /  SISTEMI PLANETARI
#     Percorso:     GENERALE
#     Codice:       51376_686681_69920
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [185BB] METODI MONTECARLO NELLA FISICA SPERIMENTALE
#     Percorso:     GENERALE
#     Codice:       51376_686682_70628
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [198BB] DOSIMETRY / DOSIMETRIA
#     Percorso:     GENERALE
#     Codice:       51376_686685_71635
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [201BB] HADRON COLLIDER PHYSICS / FISICA AI COLLISIONATORI ADRONICI
#     Percorso:     GENERALE
#     Codice:       51376_686686_71638
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [203BB] PHYSICS OF PHOTONIC DEVICES / FISICA DEI DISPOSITIVI FOTONICI
#     Percorso:     GENERALE
#     Codice:       51376_686687_71639
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [221BB] ATOM OPTICS / OTTICA ATOMICA
#     Percorso:     GENERALE
#     Codice:       51376_686690_71653
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [251BB] GRAVITATION THEORY / TEORIE DELLA GRAVITAZIONE
#     Percorso:     GENERALE
#     Codice:       51376_686692_73452
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [256BB] PHYSICS  OF GRAVITATIONAL WAVES S / FISICA DELLE ONDE GRAVITAZIONALI S
#     Percorso:     GENERALE
#     Codice:       51376_686693_73457
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [257BB] PHYSICS  OF GRAVITATIONAL WAVES /  FISICA DELLE ONDE GRAVITAZIONALI
#     Percorso:     GENERALE
#     Codice:       51376_686694_73458
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [279BB] COMPLEX SYSTEMS - NEURAL DYNAMICS / SISTEMI COMPLESSI - DINAMICHE NEURALI
#     Percorso:     GENERALE
#     Codice:       51376_686697_74416
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [306BB] EXPERIMENTAL METHODS FOR ASTROPARTICLE PHYSICS / METODOLOGIE SPERIMENTALI PER LA FISICA DELLE ASTROPARTICELLE
#     Percorso:     GENERALE
#     Codice:       51376_686699_74862
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [307BB] EXPERIMENTAL METHODS FOR ASTROPARTICLE PHYSICS S / METODOLOGIE SPERIMENTALI PER LA FISICA DELLE ASTROPARTICELLE S
#     Percorso:     GENERALE
#     Codice:       51376_686700_74863
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [308BB] SIMMETRIE DISCRETE
#     Percorso:     GENERALE
#     Codice:       51376_686701_74864
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [322BB] NONLINEAR DYNAMICS  / DINAMICA NON LINEARE
#     Percorso:     GENERALE
#     Codice:       51376_686702_75611
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [354BB] QUANTUM OPTICS AND PLASMA PHYSICS / OTTICA QUANTISTICA E PLASMI
#     Percorso:     GENERALE
#     Codice:       51376_686706_76336
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [358BB] NONPERTURBATIVE APPROACHES  TO QUANTUM FIELD THEORIES / ASPETTI NON PERTURBATIVI  DELLE TEORIE DI CAMPO QUANTISTICHE
#     Percorso:     GENERALE
#     Codice:       51376_686708_76340
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [365BB] COMPUTING METHODS FOR EXPERIMENTAL PHYSICS AND DATA ANALYSIS S
#     Percorso:     GENERALE
#     Codice:       51376_686710_76679
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [371BB] HADRON COLLIDER PHYSICS S / FISICA AI COLLISIONATORI ADRONICI S
#     Percorso:     GENERALE
#     Codice:       51376_686711_76960
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [383BB] SPECTROSCOPY AND MICROSCOPY  OF NANOMATERIALS / SPETTROSCOPIA E MICROSCOPIA DEI NANOMATERIALI
#     Percorso:     GENERALE
#     Codice:       51376_686713_77325
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [383BB] SPECTROSCOPY AND MICROSCOPY  OF NANOMATERIALS / SPETTROSCOPIA E MICROSCOPIA DEI NANOMATERIALI
#     Percorso:     GENERALE
#     Codice:       51376_686713_77325
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [384BB] MATERIAL OPTICAL SPECTROSCOPY / SPETTROSCOPIA OTTICA DEI MATERIALI
#     Percorso:     GENERALE
#     Codice:       51376_686714_77326
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [384BB] MATERIAL OPTICAL SPECTROSCOPY / SPETTROSCOPIA OTTICA DEI MATERIALI
#     Percorso:     GENERALE
#     Codice:       51376_686714_77326
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [404BB] NONPERTURBATIVE APPROACHES  TO QUANTUM FIELD THEORIES  S / ASPETTI NON PERTURBATIVI  DELLE TEORIE DI CAMPO QUANTISTICHE S
#     Percorso:     GENERALE
#     Codice:       51376_686717_77619
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [404BB] NONPERTURBATIVE APPROACHES  TO QUANTUM FIELD THEORIES  S / ASPETTI NON PERTURBATIVI  DELLE TEORIE DI CAMPO QUANTISTICHE S
#     Percorso:     GENERALE
#     Codice:       51376_686717_77619
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [408BB] PHYSICS OF SOUND
#     Percorso:     GENERALE
#     Codice:       51376_686718_77803
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [080BB] ELETTRONICA E SENSORI
#     Percorso:     ASTRONOMIA E ASTROFISICA
#     Codice:       51377_686668_66814
#     Coorte:       2023
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [091BB] COMPACT STAR PHYSICS S / FISICA DELLE STELLE COMPATTE S
#     Percorso:     ASTRONOMIA E ASTROFISICA
#     Codice:       51377_
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [0021B] MICROBIOROBOTICS
#     Percorso:     FISICA MEDICA
#     Codice:       52569_695840_78743
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [338BB] SIGNAL PROCESSING FOR PHYSICS
#     Percorso:     FISICA MEDICA
#     Codice:       52569_695842_75812
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [393BB] MEDICAL PHYSICS 2 / FISICA MEDICA 2
#     Percorso:     FISICA MEDICA
#     Codice:       52569_695865_77404
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [393BB] MEDICAL PHYSICS 2 / FISICA MEDICA 2
#     Percorso:     FISICA MEDICA
#     Codice:       52569_695865_77404
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [0008B] BIOPHYSICS FOR eFLASH THERAPY
#     Percorso:     FISICA MEDICA
#     Codice:       52569_696886_78710
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [217BB] ACCELERATOR PHYSICS / MACCHINE ACCELERATRICI
#     Percorso:     FISICA MEDICA
#     Codice:       52569_697863_71649
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [080BB] ELETTRONICA E SENSORI
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686668_66814
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [091BB] COMPACT STAR PHYSICS S / FISICA DELLE STELLE COMPATTE S
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686671_66831
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [092BB] FISICA DELLE SUPERFICI E INTERFACCE
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686672_66833
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [107BB] ACCELERATOR PHYSICS S / MACCHINE ACCELERATRICI S
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686673_66880
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [124BB] NUCLEAR MAGNETIC RESONANCE / RISONANZA MAGNETICA NUCLEARE
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686677_66913
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [140BB] GRAVITATION THEORY S / TEORIE DELLA GRAVITAZIONE S
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686678_66941
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [170BB] EXOPLANETARY SYSTEMS /  SISTEMI PLANETARI
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686681_69920
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [185BB] METODI MONTECARLO NELLA FISICA SPERIMENTALE
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686682_70628
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [198BB] DOSIMETRY / DOSIMETRIA
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686685_71635
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [201BB] HADRON COLLIDER PHYSICS / FISICA AI COLLISIONATORI ADRONICI
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686686_71638
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [203BB] PHYSICS OF PHOTONIC DEVICES / FISICA DEI DISPOSITIVI FOTONICI
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686687_71639
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [221BB] ATOM OPTICS / OTTICA ATOMICA
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686690_71653
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [251BB] GRAVITATION THEORY / TEORIE DELLA GRAVITAZIONE
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686692_73452
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [256BB] PHYSICS  OF GRAVITATIONAL WAVES S / FISICA DELLE ONDE GRAVITAZIONALI S
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686693_73457
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [257BB] PHYSICS  OF GRAVITATIONAL WAVES /  FISICA DELLE ONDE GRAVITAZIONALI
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686694_73458
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [279BB] COMPLEX SYSTEMS - NEURAL DYNAMICS / SISTEMI COMPLESSI - DINAMICHE NEURALI
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686697_74416
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [306BB] EXPERIMENTAL METHODS FOR ASTROPARTICLE PHYSICS / METODOLOGIE SPERIMENTALI PER LA FISICA DELLE ASTROPARTICELLE
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686699_74862
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [307BB] EXPERIMENTAL METHODS FOR ASTROPARTICLE PHYSICS S / METODOLOGIE SPERIMENTALI PER LA FISICA DELLE ASTROPARTICELLE S
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686700_74863
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [322BB] NONLINEAR DYNAMICS  / DINAMICA NON LINEARE
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686702_75611
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [354BB] QUANTUM OPTICS AND PLASMA PHYSICS / OTTICA QUANTISTICA E PLASMI
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686706_76336
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [358BB] NONPERTURBATIVE APPROACHES  TO QUANTUM FIELD THEORIES / ASPETTI NON PERTURBATIVI  DELLE TEORIE DI CAMPO QUANTISTICHE
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686708_76340
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [365BB] COMPUTING METHODS FOR EXPERIMENTAL PHYSICS AND DATA ANALYSIS S
#     Percorso:     FISICA TEORICA
#     Codice:       52570_
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [326BB] COMPUTATIONAL PHYSICS LABORATORY / METODI NUMERICI PER LA FISICA
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686752_75616
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [326BB] COMPUTATIONAL PHYSICS LABORATORY / METODI NUMERICI PER LA FISICA
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686752_75616
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [353BB] PLASMA PHYSICS / FISICA DEI PLASMI
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686755_76335
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [355BB] KINETIC THEORY OF PLASMAS / PLASMI TEORIA CINETICA
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686756_76337
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [360BB] COMPUTING METHODS FOR EXPERIMENTAL PHYSICS AND DATA ANALYSIS
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686758_76342
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [368BB] ASTROFISICA GENERALE
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686760_76957
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [368BB] ASTROFISICA GENERALE
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686760_76957
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [369BB] EXTRAGALACTIC ASTROPHYSICS AND COSMOLOGY / ASTROFISICA EXTRAGALATTICA E COSMOLOGIA
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686761_76958
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [370BB] CONDENSED MATTER PHYSICS
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686762_76959
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [370BB] CONDENSED MATTER PHYSICS
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686762_76959
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [373BB] PARTICLE PHYSICS S / FISICA DELLE PARTICELLE S
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686763_76962
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [374BB] COMPUTATIONAL PHYSICS LABORATORY S / METODI NUMERICI PER LA FISICA S
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686764_76973
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [375BB] OCEANOGRAFIA FISICA SU GRANDE SCALA
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686765_76974
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [376BB] QUANTUM COMPUTING AND TECHNOLOGIES
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686766_76975
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [378BB] RECENT HIGHLIGHTS IN FUNDAMENTAL INTERACTIONS
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686768_76977
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [380BB] INSTRUMENTATION FOR FUNDAMENTAL INTERACTIONS PHYSICS
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686770_77131
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [381BB] MEDICAL PHYSICS 1 /  FISICA MEDICA 1
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686771_77323
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [382BB] QUANTUM LIQUIDS
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686772_77324
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [382BB] QUANTUM LIQUIDS
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686772_77324
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [418BB] PHYSICS FOR CULTURAL HERITAGE / FISICA APPLICATA AI BENI CULTURALI
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686773_78013
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [424BB] FONDAMENTI DI OTTICA
#     Percorso:     FISICA TEORICA
#     Codice:       52570_686775_78228
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [414BB] FUNDAMENTAL INTERACTIONS LABORATORY  S / LABORATORIO INTERAZIONI FONDAMENTALI S
#     Percorso:     FISICA TEORICA
#     Codice:       52570_695823_77809
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA
#
# [0007B] QUANTUM TECHNOLOGIES FOR FUNDAMENTAL INTERACTION PHYSICS
#     Percorso:     FISICA TEORICA
#     Codice:       52570_695837_78709
#     Coorte:       2024
#     Dipartimento: DIPARTIMENTO DI FISICA

# %% [markdown]
# Sempre dalle pagine di search abbiamo il form di ricerca dei corsi di studio. Meno utile (tanto sono davvero pochi), ma tanto vale citare l'endpoing
#
# `https://unipi.coursecatalogue.cineca.it/api/v1/ricercaCorsi`
#
# in questo caso per esempio con payload
#
# ```json
# {
#     "searchString": "fisica",
#     "anno": "2024",
#     "tipoCorso": null,
#     "sede": null,
#     "lingua": null,
#     "dipartimento": null,
#     "interateneo": null,
#     "area": null
# }
# ```
#
# Nello script a seguire il risultato della richiesta. La cosa davvero folle è la quantità colossale di informazioni che viene fornita da questa chiamata API. Non solo contiene una descrizione dei corsi ma perfino di tutti gli insegnamenti!!

# %%
# Interrogazione dell'API per ottenere informazioni sui corsi di studio

import requests
import yaml

targetFile = "searchCorsi.yaml"
url = "https://unipi.coursecatalogue.cineca.it/api/v1/ricercaCorsi"
payload = {
    "searchString": "fisica",
    "anno": "2024",
    "tipoCorso": None,
    "sede": None,
    "lingua": None,
    "dipartimento": None,
    "interateneo": None,
    "area": None
}
headers = {"Content-Type": "application/json"}
response = requests.post(url, json=payload, headers=headers)

if response.status_code == 200:
    risultati = response.json()
    print(risultati)
    with open(targetFile, "w", encoding="utf-8") as f:
        yaml.dump(risultati, f, allow_unicode=True, sort_keys=False)
else:
    print(f"Errore nella richiesta: {response.status_code}")
    print(response.text)
# Out:
# [{'cod': '1709634589846', 'des_it': 'Triennali e magistrali a ciclo unico', 'des_en': 'Degree Programme', 'note_it': '', 'note_en': '', 'subgroups': [{'cod': 'AR_SCI', 'des_it': 'Scienze matematiche, fisiche e della natura', 'des_en': 'Mathematical Physical and Natural Sciences', 'cds': [{'_id': '680480e0c337ce7fb7976d85', 'gdaId': 10441, 'ugovId': None, 'extCode': 'FIS-L', 'ate_cod': 'unipi', 'aa': '2024', 'cod': '10441', 'cdsId': '10441', 'cdsCod': 'FIS-L', 'des_it': 'FISICA', 'des_en': 'PHYSICS', 'lingua_cod': 'ita', 'lingua_des_it': 'Italiano', 'lingua_des_en': 'Italian', 'area_cod': 'AR_SCI', 'area_des_it': 'Scienze matematiche, fisiche e della natura', 'area_des_en': 'Mathematical Physical and Natural Sciences', 'sede_cod': '1059', 'sede_des_it': 'Università di Pisa', 'sede_des_en': 'Università di Pisa', 'sede_utenza_sostenibile': '186', 'altreSedi': [], 'crediti_it': '180', 'crediti_en': '180', 'durata_it': '3 anni', 'durata_en': '3 years', 'normativa_cod': 'DM270', 'normativa_it': 'Riforma 270/04', 'normativa_en': '', 'classe_cod': 'L-30', 'classe_it': 'Classe delle lauree in Scienze e tecnologie fisiche', 'classe_en': 'Physics', 'interClasse_cod': '', 'interClasse_it': '', 'interClasse_en': '', 'modalita_didattica_cod': 'C', 'modalita_didattica_it': 'Convenzionale', 'modalita_didattica_en': 'Conventional', 'verificaConoscenzeRichiesteAccesso': None, 'accesso_it': 'Libero', 'accesso_en': 'Free', 'tipoAccesso': 'L', 'ordinamento_it': 'FISICA', 'ordinamento_en': 'PHYSICS', 'ordinamento_aa': 2017, 'ordinamento_stato': 'A', 'ordinamento_stato_des_it': 'Aperto', 'ordinamento_stato_des_en': 'Open', 'ordinamento_aa_cess': 9999, 'dataChiusuraRad': '2017-05-07T22:00:00.000Z', 'date_scadenze_it': None, 'date_scadenze_en': None, 'requisiti_it': {'obbligatori': [], 'optional': [], 'conoscenze': [{'tipoTitCod': 'Conoscenze richieste per l´accesso', 'tipoTitDes': "Per essere ammessi al Corso di Laurea in Fisica occorre essere in possesso di un diploma di scuola secondaria superiore o di altro titolo di studio conseguito all'estero, riconosciuto idoneo.\nIl corso non prevede il numero programmato.\n\nPer l'accesso sono richieste, oltre ad una buona capacità di comunicazione scritta e orale, abilità nel ragionamento logico e conoscenze di base di matematica e fisica acquisite nella scuola superiore.\n\nIl possesso di tali conoscenze è verificato attraverso un test d'ingresso che comunque ha come obiettivo principale, non essendo il corso a numero chiuso, l' autovalutazione da parte dello studente.\nSono previsti più momenti autovalutativi nel corso del primo semestre dell'anno di immatricolazione.\nChi non supera la prova ha come obbligo formativo quello di dover sostenere come primo esame uno relativo alle attività di base rientranti fra le discipline matematiche.\nLe modalità di svolgimento del test sono specificate nel Regolamento didattico del Corso di studi.\n\n\n"}], 'modalita': [{'tipoTitCod': 'Modalità di ammissione', 'tipoTitDes': "Per essere ammessi al Corso di Laurea in Fisica occorre essere in possesso di un diploma di scuola secondaria superiore o di altro titolo di studio conseguito all'estero, riconosciuto idoneo. Per l'accesso al Corso di Laurea in Fisica sono richieste, oltre a una buona capacità di comunicazione scritta e orale, e abilità nel ragionamento logico, le principali conoscenze di matematica e fisica classica. Il Corso di Studi non ha un numero programmato di studenti, ma si avvale del test di autovalutazione di ingresso offerto da Con.Scienze, attraverso CISIA denominato TOLC-S limitatamente ale prove di Matematica di base, Ragionamento e problemi, e Comprensione del testo, per stabilire gli eventuali OFA (obblighi formativi aggiuntivi).\nLa prova prevede una serie di 40 domande in 90 minuti in tre categorie: Matematica di Base 20 domande in 50' Ragionamento e Problemi 10 domande in 20' Comprensione del Testo 10 domande in 20' Ad ogni domanda viene assegnato un punteggio di 1 punto se corretta, -0,25 punti ...

# %% [markdown]
# Guardando le chiamate della pagina del CdL, sembra sia possibile accedere alle info del corso anche direttamente con una chiamata GET con il seguente endpoint
#
# `https://unipi.coursecatalogue.cineca.it/api/v1/corso/2024/10452?annoOrdinamento=2023`
#
# dove il parametro sull'ordinamento è irrilevante. In realtà basta indicare l'anno di erogazione (2024) e il codice del corso di studio. Ci sono codici rilevanti qui
#
# * WFI-LM, Laurea Magistrale in Fisica dell'Università di Pisa: `10452`
# * FIS-L, Laurea Triennale in Fisica dell'Università di Pisa: `10441`

# %%
# Esempio: come interrogare Course Catalogue per avere i dettagli di un corso di studi

import requests
import yaml

targetFile = "infoCdS.yaml"
url = "https://unipi.coursecatalogue.cineca.it/api/v1/corso/2024/10452"
response = requests.get(url)

if response.status_code == 200:

    data = response.json()
    print(f"Nome del CdS:        {data['des_it']}")
    print(f"Codice CdS:          {data['cdsCod']}")
    print(f"Id CdS (codice GDA): {data['cdsId']}")
    print(f"Anno accademico:     {data['aa']}")
    print(f"Ordinamento:         {data['ordinamento_aa']}")
    
    with open(targetFile, "w", encoding="utf-8") as file_yaml:
        yaml.dump(data, file_yaml, allow_unicode=True, sort_keys=False)
    
else:
    print(f"Errore nella richiesta: {response.status_code}")
# Out:
# Nome del CdS:        FISICA
# Codice CdS:          WFI-LM
# Id CdS (codice GDA): 10452
# Anno accademico:     2024
# Ordinamento:         2023

# %% [markdown]
# ## Analisi JSON di interrogazione del CdS
#
# Questo file di informazioni è particolarmente interessante e completo. Il file contiene
#
# * Alcune informazioni di carattere generale (denominazione corso, anno accademico, eccetera)
# * Un (breve) array di testi detti `requisiti_it` che descrive i requisiti di accesso al CdS, più versione inglese vuota.
# * Un array di testi detti `programmi_testi_obiettivi_it` che descrivono contenuto, feedback, etc del CdS. Anche qui la versione inglese è sostanzialmente vuota.
# * Un (breve) array `cariche_it` che indica i ruoli chiave, duplicato su `cariche_en`
# * Un array di `strutture` che contiene solo il dipartimento... che è identificato dal codice `10184`
# * Forse l'array più interessante è `percorsi`, che descrive i curricula ufficiali del CdS.
#
# ### Struttura dati dei Curricula
#
# Ogni curriculum è identificato da un codice (univoco?), che cambia anche da un anno accademico all'altro. Ci sono alcune informazioni generali, per esempio fr quelle più interessanti...
#
# ```yaml
# pdsId:      52570,     # <= codice univoco
# pdsCod:     7,         # <= codice interno GDA
# cdsId:      10452,     # <= riferimenti incrociato su CdS
# schemaId:   8950,      # <= unclear... univoco non annuale?
# schemaCod:  F TEOR,
# des_it:     FISICA TEORICA,
# ```
#
# Oltre a questo ogni curricular contiene gli insegnamenti organizzati per annualità `anni`. Per LM abbiamo primo e secondo anno. Ogni anno ha una indicazione `anno` (1 o 2), un anno di offerta e poi una lista di insegnamenti.
#
# Gli insegnamenti sono a loro volta raggurppati. In questo caso speifico al primo anno abbiamo
#
# - un codice `OO` di `Obbligatori`
# - un codice `G` di `ASTROFISICA I ANNO F TEOR (6 CFU)`
# - un codice `G` di `LABORATORI I ANNO F TEOR (9 CFU)`
# - un codice `G` di `MICROFISICA I ANNO F TEOR (9 CFU)`
# - un codice `G` di `LIBERI 15 CFU I ANNO F TEOR (15 CFU)`
#
# al secondo anno invece
#
# - un codice `OO` di `Obbligatori`... sostanzialemnte la prova finale.
# - un codice `G` di `AFFINI E INTEGRATIVE II ANNO F TEOR (18 CFU)`
#
# ### Struttura dati del singolo insegnamento
#
# I dati contengono un estratto delle informazioni chiave dell'insegnamento fra cui:
#
# - `cod` contenente il codice univoco che compare anche nei link di Course Catalogue, esempio `52570_686735_71646`
# - `adCod` è il classico codice interno dei corsi, tipo `214BB`
# - `des-it` titolo in italiano
# - `des-en` titolo in inglese
# - `crediti` ... ovvio
# - `ore` ... mi chiedo da dove arrivi questa informazione? Da GDA?
# - `statoOfferta` questo è potenzialmente interessante perché potrebbe codificare lo stato di erogazione o meno, ma è tutto da verificare...
# - `tafDes_it` vale `Caratterizzante` oppure  `Affine/Integrativa`
# - `tipo_ins_des_it` a volte (molto raramente) indica `Necessaria Attivazione`, ma non è indicato quasi ma, è quasi un errore.
# - `periodo_didattico_it` indica la semestralità
# - (solo a volte! non affidabile) è indicato il `titolare` del corso... con dentro `matricola` e `des` ossia cognome nome.
#
#
# internamente ci sono dei riferimenti incrociati, per esempio `corso_cod` conferma il codice del CdS, `corso_percorso_id` il codice del percorso (curriculum e così via) `ordinamento_aa` l'anno dell'ordinamneto di riferimento. Sembrano anche esistere alcuni link ad attività didattiche Padre e Figlie...

# %% [markdown]
# # Come affrontare la questione
#
# La quantità di dati è grossa e le API forniscono informazioni in parte ridondanti, in parti inutili. Mappare tutto in funzione dell'anno di erogazione, del piano di studi, della coorte... sembra un lavoro assurdo anche con un approcico automatico
